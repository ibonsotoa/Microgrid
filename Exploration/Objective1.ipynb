# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
co2_csv = pd.read_csv(r'C:\Users\Ibon\PycharmProjects\Microgrid\objective1_data\pymgrid_data\data\co2\co2_caiso.csv')
load_csv = pd.read_csv(r'C:\Users\Ibon\PycharmProjects\Microgrid\objective1_data\pymgrid_data\data\load\RefBldgFullServiceRestaurantNew2004_v1.3_7.1_6A_USA_MN_MINNEAPOLIS.csv')
pv_csv = pd.read_csv(r'C:\Users\Ibon\PycharmProjects\Microgrid\objective1_data\pymgrid_data\data\pv\SanFrancisco_724940TYA.csv')

# %%
print(co2_csv.head())
# Out:
#    CO2_CISO_I_kwh
# 0        0.239758
# 1        0.273659
# 2        0.270383
# 3        0.263689
# 4        0.263670

# %%
plt.figure(figsize=(10, 6))
plt.plot(co2_csv.index, co2_csv['CO2_CISO_I_kwh'], label='CO2_CISO_I_kwh')

plt.xlabel("Tiempo")
plt.ylabel("Valor")
plt.title("Series Temporales de los Datos CSV")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(load_csv.index, load_csv['Electricity:Facility [kW](Hourly)'], label='Electricity:Facility [kW](Hourly)')

plt.xlabel("Tiempo")
plt.ylabel("Valor")
plt.title("Series Temporales de los Datos CSV")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(pv_csv.index, pv_csv['GH illum (lx)'], label='GH illum (lx)')

plt.xlabel("Tiempo")
plt.ylabel("Valor")
plt.title("Series Temporales de los Datos CSV")
plt.legend()
plt.grid()
plt.show()
